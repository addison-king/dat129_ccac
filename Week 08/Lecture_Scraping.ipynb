# %% [markdown]
# Goodreads.com scraping
#
# QUESTION: What percent of python books have subtitles?
#
#     Scraping demo for DAT-129 Week 08 Lecture
#     Before scaping a pasge, check:
#         1. Are the URLs encoded in a sensible way that we can use the urllib to grab the HTML page easliy?
#         2. Are the elements on the page we want to scrape enclosed in HTML tags with distinctive class names or tag names?

# %%
import urllib
from bs4 import BeautifulSoup

def getSearchURL(term, number):
# assembles a query against goodreads.com give a search term
    #url = 'https://www.goodreads.com/search?query=%s' % (str(term))
    url = 'https://www.goodreads.com/search?page=%d&qid=gI6LAXCK22&query=%s' % (number, str(term))
    return url

def getPageText(url):
# Given a URL, fetches the raw HTML
    
    # build the request object from the given URL
    req = urllib.request.Request(url)
    # access the network via computer's standard gateway to actually retrieve the HTML from goodreads server
    with urllib.request.urlopen(req) as response:
        return response.read()

# %%
term = 'python'
number = 1
totaltitles = 0
subtitles = 0
i = 1
while i < 6:
    url = getSearchURL(term, i)
    pageText = getPageText(url)

    soup = BeautifulSoup(pageText, 'html.parser')
    bookatags = soup.find_all('a', 'bookTitle')
    
    for book in bookatags:
        title = book.find('span').string
        print('\t', title)
        totaltitles += 1
        if ":" in title:
            subtitles += 1
    print('~~~~~~~~~~~~~~~~~~~~~Page:', i,'~~~~~~~~~~~~~~~~~~~~~')
    i += 1
print('\nTotal titles: ', totaltitles)
subts = subtitles/totaltitles*100
print(subtitles, 'books contain a subtitle')
print(subts, '% of books have subtitles', sep='')
# Out:
# 	 The Pythons Autobiography by The Pythons
# 	 Learning Python
# 	 Think Python
# 	 Python Cookbook
# 	 Python for Data Analysis
# 	 Programming Python
# 	 Python Tricks
# 	 Python
# 	 The Greedy Python
# 	 Python: Programming: Your Step By Step Guide To Easily Learn Python in 7 Days
# 	 Python Machine Learning
# 	 Python for Everybody: Exploring Data in Python 3
# 	 Python Programming for Beginners: An Introduction to the Python Computer Language and Computer Programming (Python, Python 3, Python Tutorial)
# 	 Python: 3 Manuscripts in 1 book: - Python Programming For Beginners - Python Programming For Intermediates - Python Programming for Advanced
# 	 Black Hat Python: Python Programming for Hackers and Pentesters
# 	 Effective Python: 59 Specific Ways to Write Better Python
# 	 Monty Python Speaks!
# 	 Learn Python The Hard Way
# 	 Python for Kids
# 	 Python Pocket Reference
# ~~~~~~~~~~~~~~~~~~~~~Page: 1 ~~~~~~~~~~~~~~~~~~~~~
# 	 Deep Learning with Python
# 	 Dive Into Python
# 	 Head First Python
# 	 Diaries 1969-1979: The Python Years  (Palin Diaries, #1)
# 	 Fluent Python: Clear, Concise, and Effective Programming
# 	 Gray Hat Python: Python Programming for Hackers and Reverse Engineers
# 	 Core Python Programming
# 	 Natural Language Processing with Python
# 	 Python for Informatics: Exploring Information
# 	 Python's Embrace (Bitten Point, #3)
# 	 Computer Science With Python (textbook XII)
# 	 Data Science from Scratch: First Principles with Python
# 	 Automate the Boring Stuff with Python: Practical Programming for Total Beginners
# 	 Plague of Pythons
# 	 Python: The Complete Reference
# 	 PYTHON: PROGRAMMING: A BEGINNER’S GUIDE TO LEARN PYTHON IN 7 DAYS
# 	 Python Algorithms: Mastering Basic Algorithms in the Python Language
# 	 Python Essential Reference
# 	 A Million Little Pieces of Feces
# 	 A Byte of Python
# ~~~~~~~~~~~~~~~~~~~~~Page: 2 ~~~~~~~~~~~~~~~~~~~~~
# 	 The Complete Monty Python's Flying Circus: All the Words: Volume 1
# 	 Python in a Nutshell
# 	 Dive Into Python 3
# 	 Python Programming: Your Beginner Guide To Learn Python in 7 Days: ( python guide , learning python , python programming projects , python tricks , python 3 )
# 	 Python (2nd Edition): Learn Python in One Day and Learn It Well. Python for Beginners with Hands-on Project. (Learn Coding Fast with Hands-On Project Book 1)
# 	 Test-Driven Web Development with Python
# 	 Monty Python's Big Red Book
# 	 Python Crash Course: A Hands-On, Project-Based Introduction to Programming
# 	 Core Python Programming
# 	 Introduction to Computation and Programming Using Python
# 	 Divinity and The Python
# 	 Monty Python and the Holy Grail: Screenplay
# 	 Python Programming for the Absolute Beginner
# 	 Programming in Python 3: A Complete Introduction to the Python Language
# 	 The Quick Python Book
# 	 Python Programming: An Introduction to Computer Science
# 	 Python: Your Beginner’s Guide To Easily Learn Python in 7 Days
# 	 The First 200 Years of Monty Python
# 	 Python 3 Object Oriented Programming
# 	 Python: For Beginners: A Crash Course Guide To Learn Python in 1 Week
# ~~~~~~~~~~~~~~~~~~~~~Page: 3 ~~~~~~~~~~~~~~~~~~~~~
# 	 Doing Math with Python
# 	 Monty Python Live!
# 	 Beginning Python: From Novice to Professional
# 	 Learn Python in One Day and Learn It Well: Python for Beginners with Hands-on Project. The only book you need to start coding in Python immediately
# 	 Daddy Biker (Pythons MC, #1)
# 	 Pro Python
# 	 Core Python Programming
# 	 Expert Python Programming
# 	 Treading on Python Volume 1: Foundations of Python
# 	 Python For Dummies
# 	 Practical Python and OpenCV
# 	 Python Data Science Handbook: Tools and Techniques for Developers
# 	 Python Programming: Using Problem Solving Approach
# 	 Monty Python and Philosophy: Nudge Nudge, Think Think!
# 	 The Brand New Monty Python Papperbok
# 	 Building Machine Learning Systems with Python
# 	 The Complete Monty Python's Flying Circus: All the Words, Vol. 2
# 	 Python Programming For Beginners: Learn The Basics Of Python Programming
# 	 Illustrated Guide to Python 3: A Complete Walkthrough of Beginning Python with Unique Illustrations Showing how Python Really Works. Now covers Python 3.6 (Treading on Python Book 4)
# 	 Programming the Raspberry Pi: Getting Started with Python
# ~~~~~~~~~~~~~~~~~~~~~Page: 4 ~~~~~~~~~~~~~~~~~~~~~
# 	 Poisonous Pythons Paralyze Pennsylvania (American Chillers, #11)
# 	 Python: Up and Running With Python. Easy To Learn Python Programming For Beginners (Python, Python Programming, Python CookBook) (Python: Up and Running ... Python Programming For Begginers Book 1)
# 	 Learn Python Visually
# 	 Beginning Python: Using Python 2.6 and Python 3.1
# 	 Treading on Python Volume 2: Intermediate Python
# 	 Daddy Protector (Pythons MC, #2)
# 	 Flask Web Development: Developing Web Applications with Python
# 	 Data Structure and Algorithmic Thinking with Python
# 	 Introducing Python: Modern Computing in Simple Packages
# 	 Python Scripting for ArcGIS
# 	 Python: Python Programming: A Complete Practical Guide For Beginners To Master Python Programming Language
# 	 Python: The Fundamentals Of Python Programming: A Complete Beginners Guide To Python Mastery.
# 	 Let Us Python
# 	 Introduction to Machine Learning with Python: A Guide for Data Scientists
# 	 PYTHON: PYTHON'S COMPANION, A STEP BY STEP GUIDE FOR BEGINNERS TO START CODING TODAY! (INCLUDES A 6 PAGE PRINTABLE CHEAT SHEET)(PYTHON FOR BEGINNERS, PYTHON FOR DUMMIES, PYTHON PROGRAMMING)
# 	 Data Structures and Algorithms in Python
# 	 Invent Your Own Computer Games with Python
# 	 Python Isle
# 	 Making Games with Python & Pygame
# 	 Hacking Secret Ciphers with Python
# ~~~~~~~~~~~~~~~~~~~~~Page: 5 ~~~~~~~~~~~~~~~~~~~~~
#
# Total titles:  100
# 43 books contain a subtitle
# 43.0% of books have subtitles
